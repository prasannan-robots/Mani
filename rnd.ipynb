# %%
pip install llama-index-readers-file
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-dotenv
# Out:
# ...
#
# ...

# %%
from dotenv import load_dotenv
load_dotenv()
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
#from llama_index.vector_stores.chroma import ChromaVectorStore
from llama_index.core import StorageContext
from IPython.display import Markdown, display
#import chromadb
from llama_index.core.tools import QueryEngineTool, ToolMetadata
from llama_index.core.agent import ReActAgent
from llama_index.llms.openai import OpenAI
from llama_index.core.storage.chat_store import SimpleChatStore
from llama_index.core.memory import ChatMemoryBuffer
from llama_index.readers.file import PDFReader

#from llama_hub.youtube_transcript import YoutubeTranscriptReader
# create client and a new collection
#chroma_client = chromadb.EphemeralClient()
#chroma_collection = chroma_client.create_collection("selfimprovement")
#youtube_collection = chroma_client.create_collection("youtube")

# load documents
#documents = SimpleDirectoryReader("./data/raw/").load_data()
documents = PDFReader().load_data(r".\data\MF Data - March 2024 - April 2023.pdf")
# set up ChromaVectorStore and load in data
#vector_store = ChromaVectorStore(chroma_collection=chroma_collection)
#youtube_store = ChromaVectorStore(chroma_collection=youtube_collection)

#storage_context = StorageContext.from_defaults(vector_store=vector_store)
#yt_storage_context = StorageContext.from_defaults(vector_store=chat_store)
index = VectorStoreIndex.from_documents(
    documents
)


# Query Data
query_engine = index.as_query_engine()
response = query_engine.query("List the overall scheme names")
#display(Markdown(f"<b>{response}</b>"))
print(response)
# Out:
# iOvernight Fund, iiLiquid Fund, iiiUltra Short Duration Fund, ivLow Duration Fund, vMoney Market Fund, viShort Duration Fund, viiMedium Duration Fund, viiiMedium to Long Duration Fund, ixLong Duration Fund, xDynamic Bond Fund, xiCorporate Bond Fund, xiiCredit Risk Fund, xiiiBanking and PSU Fund, xivGilt Fund, xvGilt Fund with 10 year constant duration, xviFloater Fund

# %%
query_engine.query("List the overall Categories in the form of list with a json key categories and list of columns in the file with a json key columns").response
# Out:
# '{\n    "categories": ["Open ended Schemes", "Close Ended Schemes"],\n    "columns": ["Scheme Name", "Number of Schemes", "Total Investment", "Total Units", "Total Cost Price", "Total Market Value", "Number of Transactions", "Transaction Cost"]\n}'

# %%
query_engine2.query("Perform analysis of the funds")
# Out:
# Response(response="The analysis of the funds shows that there are three main categories: Open-ended Schemes, Close-ended Schemes, and Interval Schemes. Open-ended Schemes have the highest total value, followed by Close-ended Schemes and Interval Schemes. Within each category, there are subcategories such as Income/Debt Oriented Schemes and Growth/Equity Oriented Schemes. The data provides details on the total values, performance metrics, and number of schemes in each subcategory, allowing for a comprehensive analysis of the funds' distribution and performance across different types of schemes.", source_nodes=[NodeWithScore(node=TextNode(id_='f6eb5b7c-ee13-438e-8bd0-6933ace32bfd', embedding=None, metadata={'page_label': '2', 'file_name': 'MF Data - March 2024 - April 2023.pdf'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='0728aabc-d40f-4d1a-a4aa-363e45045e91', node_type=<ObjectType.DOCUMENT: '4
# ...

# %%
index.as_chat_engine().chat("List the overall scheme names")
# Out:
# AgentChatResponse(response='The overall scheme names are:\n1. Overnight Fund\n2. Liquid Fund\n3. Ultra Short Duration Fund\n4. Low Duration Fund\n5. Money Market Fund\n6. Short Duration Fund\n7. Medium Duration Fund\n8. Medium to Long Duration Fund\n9. Long Duration Fund\n10. Dynamic Bond Fund\n11. Corporate Bond Fund\n12. Credit Risk Fund\n13. Banking and PSU Fund\n14. Gilt Fund\n15. Gilt Fund with 10 year constant duration\n16. Floater Fund', sources=[ToolOutput(content='iOvernight Fund, iiLiquid Fund, iiiUltra Short Duration Fund, ivLow Duration Fund, vMoney Market Fund, viShort Duration Fund, viiMedium Duration Fund, viiiMedium to Long Duration Fund, ixLong Duration Fund, xDynamic Bond Fund, xiCorporate Bond Fund, xiiCredit Risk Fund, xiiiBanking and PSU Fund, xivGilt Fund, xvGilt Fund with 10 year constant duration, xviFloater Fund', tool_name='query_engine_tool', raw_input={'input': 'List the overall scheme names'}, raw_output=Response(response='iOvernight Fund, iiLiquid Fund, 
# ...

# %%
from llama_index.readers.file import CSVReader
from pathlib import Path
documents2 = CSVReader().load_data(Path(r".\data\MF Data - March 2024 - April 2023.csv"))
index2 = VectorStoreIndex.from_documents(
    documents
)


# Query Data
query_engine2 = index2.as_query_engine()

# %%
pip install tabula-py
# Out:
# ...
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/12.0 MB 1.1 MB/s eta 0:00:11
#     --------------------------------------- 0.2/12.0 MB 2.1 MB/s eta 0:00:06
#    - -------------------------------------- 0.3/12.0 MB 2.1 MB/s eta 0:00:06
#    - -------------------------------------- 0.4/12.0 MB 1.9 MB/s eta 0:00:07
#    - -------------------------------------- 0.4/12.0 MB 1.7 MB/s eta 0:00:07
#    - -------------------------------------- 0.5/12.0 MB 1.6 MB/s eta 0:00:08
#    - -------------------------------------- 0.6/12.0 MB 1.6 MB/s eta 0:00:08
#    -- ------------------------------------- 0.6/12.0 MB 1.5 MB/s eta 0:00:08
#    -- ------------------------------------- 0.7/12.0 MB 1.5 MB/s eta 0:00:08
# ...

# %%
import tabula
tabula.convert_into(r".\data\MF Data - March 2024 - April 2023.pdf", r".\data\MF Data - March 2024 - April 2023.csv", output_format="csv", pages='all')
# Out:
# Error importing jpype dependencies. Fallback to subprocess.
# No module named 'jpype'

# %%
import pandas as pd

# Path to the CSV file
csv_path = "data\MF Data - March 2024 - April 2023.csv"

# Read the CSV file
df = pd.read_csv(csv_path, header=None)

# Concatenate the data from different lines into a single row
#row_data = df.apply(lambda x: ','.join(x.dropna().astype(str)), axis=1)

# Create a new DataFrame with the concatenated row data
#new_df = pd.DataFrame([row_data])

# Save the new DataFrame to a CSV file
#new_df.to_csv("output.csv", index=False, header=False)
df.iloc[1]
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\M'
# <>:4: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\prasannan-robots\AppData\Local\Temp\ipykernel_9828\733790677.py:4: SyntaxWarning: invalid escape sequence '\M'
#   csv_path = "data\MF Data - March 2024 - April 2023.csv"
# 0                                                   Sr
# 1                                          Scheme Name
# 2                 No. of\rSchemes\ras on\rMarch,\r2024
# 3                    No. of Folios\ras on March,\r2024
# 4    Funds\rMobilized\rfor the\rmonth of\rMarch 202...
# 5    Repurchase/\rRedemption\rfor the\rmonth of\rMa...
# 6    Net Assets\rUnder\rManagemen\rt as on\rMarch, ...
# 7    Average Net\rAssets Under\rManagemen\rt for th...
# 8    No. of\rsegregat\red\rportfolio\rs\rcreated\ra...
# 9    Net\rAssets\rUnder\rManage\rment in\rsegregat\...
# Name: 1, dtype: object

# %%
# Out:
#                                          0     \
# 0  Monthly Report for the month of March 2024
#
#                                                 1                     2     \
# 0  Sr,Scheme Name,No. of\rSchemes\ras on\rMarch,\...  A,Open ended Schemes
#
#                              3     \
# 0  I,Income/Debt Oriented Schemes
#
#                                                 4     \
# 0  i,Overnight Fund,35,9,00,146,5,22,110.92,5,29,...
#
#                                                 5     \
# 0  ii,Liquid Fund,36,17,82,854,3,13,033.72,4,71,0...
#
#                                                 6     \
# 0  iii,Ultra Short Duration Fund,24,6,33,208,18,9...
#
#                                                 7     \
# 0  iv,Low Duration Fund,20,8,77,506,13,081.17,19,...
#
#                                                 8     \
# 0  v,Money Market Fund,23,4,30,626,44,179.10,52,8...
#
#                                                 9     ... 1046  \
# ...
